# %%
import torch
import pickle
import numpy as np
import mmpretrain
import mmengine
from mmengine.fileio import get
from mmpretrain.apis import init_model
import mmengine
from mmengine.config import Config, ConfigDict, DictAction
from mmengine.evaluator import DumpResults
from mmengine.registry import RUNNERS
from mmengine.runner import Runner

# %%
# path = '/scratch/yw6594/cf/data/cifar10/cifar-10-batches-py/cifar_test_nolabels.pkl'
# data = mmengine.load(path)
# dd = data[b'data']
config = '/scratch/yw6594/cf/mmcl/cifar-img/dl_res18_exp/cifar10_resnet18_c32_kaggle.py'
model_cpt = '/scratch/yw6594/cf/mmcl/out/dl/res18-c10/cifarbase/epoch_200.pth'

cfg = Config.fromfile(config)
cfg.load_from = model_cpt
runner = Runner.from_cfg(cfg)
# Out:
# 04/01 12:34:01 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla V100-PCIE-32GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: gcc (GCC) 11.3.1 20221121 (Red Hat 11.3.1-4)
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.9.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/01 12:34:01 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=128)
# data_preprocessor = dict(
#     mean=[
#         125.307,
#         122.961,
#         113.8575,
#     ],
#     num_classes=10,
#     std=[
#         51.5865,
#         50.847,
#         51.255,
#     ],
#     to_rgb=False)
# dataset_type = 'CIFAR10TEST'
# default_hooks = dict(
#     checkpoint=dict(interval=50, max_keep_ckpts=3, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = '/scratch/yw6594/cf/mmcl/out/dl/res18-c10/cifarbase/epoch_200.pth'
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         base_channels=32,
#         depth=18,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch',
#         type='ResNet_CIFAR'),
#     head=dict(
#         in_channels=256,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=10,
#         type='LinearClsHead'),
#     neck=dict(type='GlobalAveragePooling'),
#     type='ImageClassifier')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.1, momentum=0.9, type='SGD', weight_decay=0.0001),
#     paramwise_cfg=dict(custom_keys=dict(backbone=dict(lr_mult=0.99))))
# param_scheduler = dict(
#     by_epoch=True, gamma=0.1, milestones=[
#         35,
#         50,
#     ], type='MultiStepLR')
# randomness = dict(deterministic=False, seed=0)
# resume = False
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=1024,
#     dataset=dict(
#         data_root='data/cifar10/',
#         pipeline=[
#             dict(type='PackInputs'),
#         ],
#         split='test',
#         type='CIFAR10TEST'),
#     num_workers=2,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     topk=(
#         1,
#         5,
#     ), type='Accuracy')
# test_pipeline = [
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(by_epoch=True, max_epochs=70, val_interval=5)
# train_dataloader = dict(
#     batch_size=128,
#     dataset=dict(
#         dataset=dict(
#             data_root='data/cifar10',
#             pipeline=[
#                 dict(crop_size=32, padding=4, type='RandomCrop'),
#                 dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#                 dict(type='PackInputs'),
#             ],
#             split='train',
#             type='CIFAR10TEST'),
#         times=1,
#         type='RepeatDataset'),
#     num_workers=2,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(crop_size=32, padding=4, type='RandomCrop'),
#     dict(direction='horizontal', prob=0.5, type='RandomFlip'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=1024,
#     dataset=dict(
#         data_root='data/cifar10/',
#         pipeline=[
#             dict(type='PackInputs'),
#         ],
#         split='test',
#         type='CIFAR10TEST'),
#     num_workers=2,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     topk=(
#         1,
#         5,
#     ), type='Accuracy')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='UniversalVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/scratch/yw6594/cf/mmcl/out/test'
#
# 04/01 12:34:01 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/01 12:34:01 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
output = runner.test()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 output = runner.test()
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/runner/runner.py:1816, in Runner.test(self)
#    1810 if self._test_loop is None:
#    1811     raise RuntimeError(
#    1812         '`self._test_loop` should not be None when calling test '
#    1813         'method. Please provide `test_dataloader`, `test_cfg` and '
#    1814         '`test_evaluator` arguments when initializing runner.')
# -> 1816 self._test_loop = self.build_test_loop(self._test_loop)  # type: ignore
#    1818 self.call_hook('before_run')
#    1820 # make sure checkpoint-related hooks are triggered after `before_run`
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/runner/runner.py:1611, in Runner.build_test_loop(self, loop)
#    1604     loop = LOOPS.build(
#    1605         loop_cfg,
#    1606         default_args=dict(
#    1607             runner=self,
#    1608             dataloader=self._test_dataloader,
#    1609             evaluator=self._test_evaluator))
#    1610 else:
# -> 1611     loop = TestLoop(
#    1612         **loop_cfg,
#    1613         runner=self,
#    1614         dataloader=self._test_dataloader,
#    1615         evaluator=self._test_evaluator)  # type: ignore
#    1617 return loop
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/runner/loops.py:410, in TestLoop.__init__(self, runner, dataloader, evaluator, fp16)
#     405 def __init__(self,
#     406              runner,
#     407              dataloader: Union[DataLoader, Dict],
#     408              evaluator: Union[Evaluator, Dict, List],
#     409              fp16: bool = False):
# --> 410     super().__init__(runner, dataloader)
#     412     if isinstance(evaluator, dict) or isinstance(evaluator, list):
#     413         self.evaluator = runner.build_evaluator(evaluator)  # type: ignore
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/runner/base_loop.py:26, in BaseLoop.__init__(self, runner, dataloader)
#      22 if isinstance(dataloader, dict):
#      23     # Determine whether or not different ranks use different seed.
#      24     diff_rank_seed = runner._randomness_cfg.get(
#      25         'diff_rank_seed', False)
# ---> 26     self.dataloader = runner.build_dataloader(
#      27         dataloader, seed=runner.seed, diff_rank_seed=diff_rank_seed)
#      28 else:
#      29     self.dataloader = dataloader
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/runner/runner.py:1370, in Runner.build_dataloader(dataloader, seed, diff_rank_seed)
#    1368 dataset_cfg = dataloader_cfg.pop('dataset')
#    1369 if isinstance(dataset_cfg, dict):
# -> 1370     dataset = DATASETS.build(dataset_cfg)
#    1371     if hasattr(dataset, 'full_init'):
#    1372         dataset.full_init()
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/registry/registry.py:570, in Registry.build(self, cfg, *args, **kwargs)
#     548 def build(self, cfg: dict, *args, **kwargs) -> Any:
#     549     """Build an instance.
#     550
#     551     Build an instance by calling :attr:`build_func`.
#    (...)
#     568         >>> model = MODELS.build(cfg)
#     569     """
# --> 570     return self.build_func(cfg, *args, **kwargs, registry=self)
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/registry/build_functions.py:121, in build_from_cfg(cfg, registry, default_args)
#     119     obj = obj_cls.get_instance(**args)  # type: ignore
#     120 else:
# --> 121     obj = obj_cls(**args)  # type: ignore
#     123 if (inspect.isclass(obj_cls) or inspect.isfunction(obj_cls)
#     124         or inspect.ismethod(obj_cls)):
#     125     print_log(
#     126         f'An `{obj_cls.__name__}` instance is built from '  # type: ignore # noqa: E501
#     127         'registry, and its implementation can be found in '
#     128         f'{obj_cls.__module__}',  # type: ignore
#     129         logger='current',
#     130         level=logging.DEBUG)
#
# File /scratch/yw6594/cf/mmcl/mmpretrain/datasets/cifar.py:288, in CIFAR10TEST.__init__(self, data_root, split, metainfo, download, data_prefix, test_mode, **kwargs)
#     284     raise RuntimeError('Please set ``data_root`` to'
#     285                        'specify the dataset path')
#     287 self.download = download
# --> 288 super().__init__(
#     289     # The CIFAR dataset doesn't need specify annotation file
#     290     ann_file='',
#     291     metainfo=metainfo,
#     292     data_root=data_root,
#     293     data_prefix=dict(root=data_prefix),
#     294     test_mode=test_mode,
#     295     **kwargs)
#
# File /scratch/yw6594/cf/mmcl/mmpretrain/datasets/base_dataset.py:101, in BaseDataset.__init__(self, ann_file, metainfo, data_root, data_prefix, filter_cfg, indices, serialize_data, pipeline, test_mode, lazy_init, max_refetch, classes)
#      98     else:
#      99         transforms.append(transform)
# --> 101 super().__init__(
#     102     ann_file=ann_file,
#     103     metainfo=metainfo,
#     104     data_root=data_root,
#     105     data_prefix=data_prefix,
#     106     filter_cfg=filter_cfg,
#     107     indices=indices,
#     108     serialize_data=serialize_data,
#     109     pipeline=transforms,
#     110     test_mode=test_mode,
#     111     lazy_init=lazy_init,
#     112     max_refetch=max_refetch)
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/dataset/base_dataset.py:247, in BaseDataset.__init__(self, ann_file, metainfo, data_root, data_prefix, filter_cfg, indices, serialize_data, pipeline, test_mode, lazy_init, max_refetch)
#     245 # Full initialize the dataset.
#     246 if not lazy_init:
# --> 247     self.full_init()
#
# File /scratch/yw6594/cf/mmcl/mmpretrain/datasets/base_dataset.py:178, in BaseDataset.full_init(self)
#     175 def full_init(self):
#     176     """Load annotation file and set ``BaseDataset._fully_initialized`` to
#     177     True."""
# --> 178     super().full_init()
#     180     #  To support the standard OpenMMLab 2.0 annotation format. Generate
#     181     #  metainfo in internal format from standard metainfo format.
#     182     if 'categories' in self._metainfo and 'classes' not in self._metainfo:
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/dataset/base_dataset.py:298, in BaseDataset.full_init(self)
#     296     return
#     297 # load data information
# --> 298 self.data_list = self.load_data_list()
#     299 # filter illegal data, such as data that has no annotations.
#     300 self.data_list = self.filter_data()
#
# File /scratch/yw6594/cf/mmcl/mmpretrain/datasets/cifar.py:311, in CIFAR10TEST.load_data_list(self)
#     309 file_path = join_path(root, self.base_folder, self.kaggle_list[-1])
#     310 import mmengine
# --> 311 entry = mmengine.load(file_path)
#     312 imgs.append(entry[b'data'])
#     314 # for file_name, _ in downloaded_list:
#     315 #     file_path = join_path(root, self.base_folder, file_name)
#     316 #     entry = pickle.loads(get(file_path), encoding='latin1')
#    (...)
#     320 #     else:
#     321 #         gt_labels.extend(entry['fine_labels'])
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/fileio/io.py:855, in load(file, file_format, file_client_args, backend_args, **kwargs)
#     853             obj = handler.load_from_fileobj(f, **kwargs)
#     854     else:
# --> 855         with BytesIO(file_backend.get(file)) as f:
#     856             obj = handler.load_from_fileobj(f, **kwargs)
#     857 elif hasattr(file, 'read'):
#
# File /vast/yw6594/miniconda/envs/cl/lib/python3.8/site-packages/mmengine/fileio/backends/local_backend.py:33, in LocalBackend.get(self, filepath)
#      18 def get(self, filepath: Union[str, Path]) -> bytes:
#      19     """Read bytes from a given ``filepath`` with 'rb' mode.
#      20
#      21     Args:
#    (...)
#      31         b'hello world'
#      32     """
# ---> 33     with open(filepath, 'rb') as f:
#      34         value = f.read()
#      35     return value
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cifar10/cifar-10-batches-py/cifar_test_nolabels.pkl'

# %%
# Out:
# dict_keys([b'data'])
# dict_values([array([[133, 136, 136, ..., 226, 225, 224],
#        [160, 177, 176, ...,  89,  89,  88],
#        [255, 255, 255, ..., 211, 213, 215],
#        ...,
#        [ 29,  29,  45, ..., 156, 155, 154],
#        [124, 123, 126, ...,  49,  49,  51],
#        [255, 255, 255, ..., 250, 251, 255]], dtype=uint8)])
